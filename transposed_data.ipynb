# %% [markdown]
# <a href="https://colab.research.google.com/github/Alonge9500/Alonge9500/blob/main/transposed_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('birth.csv')
df
# Out:
#   Country Name Country Code    1960    1961    1962    1963    1964    1965  \
# 0        Ghana          GHA  49.804  49.347  49.166  48.989  48.361  47.878
# 1      Nigeria          NGA  46.107  46.243  46.426  46.421  46.463  46.467
#
#      1966    1967  ...    2014    2015    2016    2017    2018    2019  \
# 0  47.351  47.233  ...  31.834  31.713  30.527  28.978  29.025  28.572
# 1  46.514  46.527  ...  40.069  39.510  39.128  38.689  38.248  37.849
#
#      2020    2021    2022  2023
# 0  28.038  27.548  27.080   NaN
# 1  37.467  37.117  36.611   NaN
#
# [2 rows x 66 columns]

# %%
df_transposed = df.transpose()

# %%
df_transposed
# Out:
#                    0        1
# Country Name   Ghana  Nigeria
# Country Code     GHA      NGA
# 1960          49.804   46.107
# 1961          49.347   46.243
# 1962          49.166   46.426
# ...              ...      ...
# 2019          28.572   37.849
# 2020          28.038   37.467
# 2021          27.548   37.117
# 2022           27.08   36.611
# 2023             NaN      NaN
#
# [66 rows x 2 columns]

# %%
df_transposed
df_transposed.to_csv('transposed.csv')
